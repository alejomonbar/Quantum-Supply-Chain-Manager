# %% [markdown]
# Two datasets were generated, one with about 20000 data in the training set and the other with 2000 in the test set, one unbalanced and the other balanced in the binary classification, which is shown in the following figure.
#
# ![classical_results.png](attachment:classical_results.png)

# %% [markdown]
# For the quantum computing case, the following scheme is generated for each experiment and it has 3 different ansatz based on 3 tensor networks (TN). With  only 16 variables we designed the amplitud embedding an one layer for each TN.
#
# ![quantum_circuits.png](attachment:quantum_circuits.png)

# %% [markdown]
# For the case of tensor networks are MERA, TTN and MPS, whose basic circuit for 4 qubits is presented below, each of the circuits were made since having 16 variables of data analysis can be done the amplitude embedding.
#
# The case with MERA with 1 layer is better than the the classical with 2000, obtain similar result with the 20000 samples in classical train set
#
# ![quantum_results.png](attachment:quantum_results.png)

# %% [markdown]
# https://arxiv.org/pdf/2204.03455.pdf

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# %%
ConfusionMatrixDisplay(confusion_matrix).plot()

# %%
confusion_matrix = np.array([[4684, 346],[829, 300]])
plt.figure()
plt.imshow(confusion_matrix, cmap="Blues")
for i in range(2):
    for j in range(2):
        plt.text(j, i, format(confusion_matrix[i, j]),
                ha="center", va="center",
                color="white" if confusion_matrix[i, j] > 2500 else "black", fontsize=18)
plt.xticks([0,1], [0,1], fontsize=14)
plt.yticks([0,1], [0,1], fontsize=14)
plt.xlabel("Predicted Label", fontsize=14)
plt.ylabel("True Label", fontsize=14)
plt.colorbar()

# %%
confusion_matrix = np.array([[3690, 1070],[182, 947]])
plt.figure()
plt.imshow(confusion_matrix, cmap="Blues")
for i in range(2):
    for j in range(2):
        plt.text(j, i, format(confusion_matrix[i, j]),
                ha="center", va="center",
                color="white" if confusion_matrix[i, j] > 2500 else "black", fontsize=18)
plt.xticks([0,1], [0,1], fontsize=14)
plt.yticks([0,1], [0,1], fontsize=14)
plt.xlabel("Predicted Label", fontsize=14)
plt.ylabel("True Label", fontsize=14)
plt.colorbar()

# %%
confusion_matrix = np.array([[3835, 1195],[237, 892]])
plt.figure()
plt.imshow(confusion_matrix, cmap="Blues")
for i in range(2):
    for j in range(2):
        plt.text(j, i, format(confusion_matrix[i, j]),
                ha="center", va="center",
                color="white" if confusion_matrix[i, j] > 2500 else "black", fontsize=18)
plt.xticks([0,1], [0,1], fontsize=14)
plt.yticks([0,1], [0,1], fontsize=14)
plt.xlabel("Predicted Label", fontsize=14)
plt.ylabel("True Label", fontsize=14)
plt.colorbar()

# %%
https://arxiv.org/pdf/2010.07335.pdf
# Out:
#   Input In [1]
#     https://arxiv.org/pdf/2010.07335.pdf
#           ^
# SyntaxError: invalid syntax

# %%
https://arxiv.org/pdf/2105.10162.pdf
# Out:
#   Input In [2]
#     https://arxiv.org/pdf/2105.10162.pdf
#           ^
# SyntaxError: invalid syntax

# %%
https://arxiv.org/pdf/2203.01340.pdf maria
    https://arxiv.org/pdf/1810.03787.pdf MERA 
        https://arxiv.org/pdf/1905.01426.pdf MERA 2
            
            https://pennylane.ai/qml/demos/tutorial_tn_circuits.html
